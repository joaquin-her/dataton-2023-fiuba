# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[45], line 2
#       1 import pandas as pd
# ----> 2 import seaborn
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
estaciones = pd.read_csv("estaciones_bicis .csv")
marzo = pd.read_csv("marzo_dataset .csv")
febrero = pd.read_csv("febrero_dataset.csv")
estaciones.head()
# Out:
#     ID  NUMERO               NOMBRE  \
# 0  202       1  FACULTAD DE DERECHO
# 1    2       2             RETIRO I
# 2    3       3               ADUANA
# 3    4       4           PLAZA ROMA
# 4    5       5         PLAZA ITALIA
#
#                                            DIRECCION       BARRIO     COMUNA  \
# 0                   2120 Figueroa Alcorta, Pres. Av.     RECOLETA   COMUNA 2
# 1  Ramos Mejia, Jose Maria, Dr. Av. & Del Liberta...       RETIRO   COMUNA 1
# 2                                  Moreno & Azopardo    MONSERRAT   COMUNA 1
# 3                                 Lavalle & Bouchard  SAN NICOLAS   COMUNA 1
# 4                                 2601 Sarmiento Av.      PALERMO  COMUNA 14
#
#    EMPLAZAMIENTO  ANCLAJES  QUEDA ABIERTA  Latitud  Longitud
# 0         VEREDA      30.0              1 -34.5842  -58.3905
# 1  PLAZA ABIERTA      36.0              1 -34.5927  -58.3751
# 2         VEREDA      20.0              1 -34.6112  -58.3696
# ...

# %%
print(len(estaciones))
print(estaciones["EMPLAZAMIENTO"].unique())
estaciones.describe()
# Out:
# 471
# ['VEREDA' 'PLAZA ABIERTA' 'CALZADA' 'PLAZOLETA' 'PLAZA CERRADA'
#  'VEREDA/dentro del ministerio' 'PLAZA']
#                ID      NUMERO    ANCLAJES  QUEDA ABIERTA     Latitud  \
# count  471.000000  471.000000  469.000000     471.000000  471.000000
# mean   260.628450  204.095541   18.287846       0.912951  -34.603935
# std    149.186874  115.839422    4.925544       0.751496    0.028303
# min      2.000000    1.000000    6.000000       0.000000  -34.683200
# 25%    131.500000  104.500000   16.000000       1.000000  -34.623250
# 50%    263.000000  206.000000   20.000000       1.000000  -34.604800
# 75%    387.500000  307.000000   20.000000       1.000000  -34.585400
# max    519.000000  400.000000   48.000000       3.000000  -34.541400
#
#          Longitud
# count  471.000000
# mean   -58.431409
# std      0.041611
# min    -58.521700
# 25%    -58.464900
# 50%    -58.432800
# 75%    -58.397050
# max    -58.355600

# %%
marzo.head()
# Out:
#         Id_recorrido duracion_recorrido fecha_origen_recorrido  \
# 0  17415328BAEcobici                520    2023-03-04 15:17:55
# 1  17599063BAEcobici                847    2023-03-22 16:32:46
# 2  17575845BAEcobici              2,084    2023-03-20 19:23:56
# 3  17665972BAEcobici                476    2023-03-29 13:23:15
# 4  17425224BAEcobici              1,136    2023-03-06 08:33:28
#
#   id_estacion_origen nombre_estacion_origen id_estacion_destino  \
# 0       130BAEcobici        130 - RETIRO II        448BAEcobici
# 1       440BAEcobici          142 - ARMENIA         58BAEcobici
# 2        94BAEcobici           094 - GÚZMAN        236BAEcobici
# 3       158BAEcobici       158 - VILLARROEL        206BAEcobici
# 4       116BAEcobici  116 - HOSPITAL ALEMÁN        114BAEcobici
#
#         nombre_estacion_destino       id_usuario  género
# 0               393 - Barrio 31  444458BAEcobici  FEMALE
# 1       058 - Ministro Carranza  711954BAEcobici   OTHER
# ...

# %%
print(min(marzo["duracion_recorrido"]))
marzo.describe()
# Out:
# 1,000
#              Id_recorrido duracion_recorrido fecha_origen_recorrido  \
# count               10000              10000                  10000
# unique              10000               2713                   9965
# top     17415328BAEcobici                608    2023-03-20 12:06:10
# freq                    1                 17                      2
#
#        id_estacion_origen nombre_estacion_origen id_estacion_destino  \
# count               10000                  10000               10000
# unique                318                    318                 317
# top          175BAEcobici     147 - Constitución        175BAEcobici
# freq                  148                    148                 120
#
#        nombre_estacion_destino       id_usuario género
# count                    10000            10000   9956
# unique                     317             7953      3
# top         147 - Constitución  195874BAEcobici   MALE
# ...

# %%
print(febrero.describe())
febrero.head()
